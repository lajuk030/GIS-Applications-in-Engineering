# %% [markdown]
# <h1><font color = 'red'> <center>GIS Apps in Engineering: Assignment 2</h1>
# <h3><font color = 'blue'> <center>Lajuk</h3>

# %% [markdown]
# **Read data and reproject to same CRS EPSG 3083**

# %%
import geopandas as gpd
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from shapely.geometry import Point, LineString, Polygon
import os

# %%
path = "/Users/washemuzzamanlajuk/Desktop/Fall 2025/GIS/Assignment-2/Data"
os.chdir(path)

# %%
ftexas = "County_Boundaries.shp" 
fwells = "TWDB_Groundwater.shp"
froad = "tl_2019_48_prisecroads.shp"
texas = gpd.read_file(ftexas)
wells = gpd.read_file(fwells)
road = gpd.read_file(froad)

# %%
crsp = "epsg:3083"
texasp = texas.to_crs(crsp)
wellsp = wells.to_crs(crsp)
roadp = road.to_crs(crsp)

# %%
fig,ax = plt.subplots(figsize=(12,10))
roadp.plot(ax=ax,color ='blue', linewidth =1,label = 'Roads')
texasp.plot(ax=ax,color ='lightgrey', edgecolor = 'black', alpha =0.5)
wellsp.plot(ax=ax,color ='red', markersize=3,label = 'Wells')
plt.grid()
plt.xlabel ('Easting')
plt.ylabel ('Northing')
plt.legend()
plt.title("Major Roads and Wells in Texas")
# Out:
# Text(0.5, 1.0, 'Major Roads and Wells in Texas')

# %%
texasp.head()
# Out:
#    CMPTRL_CNT  DPS_CNTY_N FIPS_ST_CN  TXDOT_CNTY  TXDOT_DIST   CNTY_NM  \
# 0         232         232      48463         232          15    Uvalde
# 1         143         143      48285         143          13    Lavaca
# 2          20          20      48039          20          12  Brazoria
# 3         241         241      48481         241          13   Wharton
# 4         163         163      48325         163          15    Medina
#
#    CNTY_NBR  DIST_NBR  GID                                           geometry
# 0       232        15   35  POLYGON ((1548581.291 7218735.879, 1548468.505...
# 1       143        13   36  POLYGON ((1802991.419 7283200.383, 1803004.233...
# 2        20        12   37  POLYGON ((1955932.657 7285025.893, 1955942.414...
# 3       241        13   38  POLYGON ((1869676.725 7285704.18, 1869702.421 ...
# 4       163        15   39  POLYGON ((1557004.141 7228370.693, 1557000.037...

# %%
texasp['AreaSQMI']=texasp.area*(0.000621371**2)

# %%
texasp.head()
# Out:
#    CMPTRL_CNT  DPS_CNTY_N FIPS_ST_CN  TXDOT_CNTY  TXDOT_DIST   CNTY_NM  \
# 0         232         232      48463         232          15    Uvalde
# 1         143         143      48285         143          13    Lavaca
# 2          20          20      48039          20          12  Brazoria
# 3         241         241      48481         241          13   Wharton
# 4         163         163      48325         163          15    Medina
#
#    CNTY_NBR  DIST_NBR  GID                                           geometry  \
# 0       232        15   35  POLYGON ((1548581.291 7218735.879, 1548468.505...
# 1       143        13   36  POLYGON ((1802991.419 7283200.383, 1803004.233...
# 2        20        12   37  POLYGON ((1955932.657 7285025.893, 1955942.414...
# 3       241        13   38  POLYGON ((1869676.725 7285704.18, 1869702.421 ...
# 4       163        15   39  POLYGON ((1557004.141 7228370.693, 1557000.037...
#
#       AreaSQMI
# 0  1564.693610
# 1   971.076790
# 2  1486.249672
# 3  1094.348572
# 4  1339.619141

# %%
area = np.sum(texasp.AreaSQMI)
print(area)
# Out:
# 267232.3345392067

# %% [markdown]
# <h5> Dissolve the Countys in Texas

# %%
texasd = texasp.dissolve() #Requires () as it is a method

# %%
texasd.plot()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
texasd.head()
# Out:
#                                             geometry  CMPTRL_CNT  DPS_CNTY_N  \
# 0  POLYGON ((1276002.91 7307500.853, 1276009.411 ...         232         232
#
#   FIPS_ST_CN  TXDOT_CNTY  TXDOT_DIST CNTY_NM  CNTY_NBR  DIST_NBR  GID  \
# 0      48463         232          15  Uvalde       232        15   35
#
#      AreaSQMI
# 0  1564.69361

# %%
texasd.columns
# Out:
# Index(['geometry', 'CMPTRL_CNT', 'DPS_CNTY_N', 'FIPS_ST_CN', 'TXDOT_CNTY',
#        'TXDOT_DIST', 'CNTY_NM', 'CNTY_NBR', 'DIST_NBR', 'GID', 'AreaSQMI'],
#       dtype='object')

# %%
texasd = texasd.drop(columns=['AreaSQMI'])

# %%
texasd.head()
# Out:
#                                             geometry  CMPTRL_CNT  DPS_CNTY_N  \
# 0  POLYGON ((1276002.91 7307500.853, 1276009.411 ...         232         232
#
#   FIPS_ST_CN  TXDOT_CNTY  TXDOT_DIST CNTY_NM  CNTY_NBR  DIST_NBR  GID
# 0      48463         232          15  Uvalde       232        15   35

# %%
texasd['AreaSQMI']=texasd.area*np.power(0.000621371,2)

# %%
texasd.head()
# Out:
#                                             geometry  CMPTRL_CNT  DPS_CNTY_N  \
# 0  POLYGON ((1276002.91 7307500.853, 1276009.411 ...         232         232
#
#   FIPS_ST_CN  TXDOT_CNTY  TXDOT_DIST CNTY_NM  CNTY_NBR  DIST_NBR  GID  \
# 0      48463         232          15  Uvalde       232        15   35
#
#         AreaSQMI
# 0  267232.334434

# %%
roadp['LengthMI'] = roadp.length*0.0006213712
roadp.head()
# Out:
#         LINEARID             FULLNAME RTTYP  MTFCC  \
# 0  1102671600066  S Walton Walker Rmp     M  S1200
# 1  1102671599582  S Walton Walker Rmp     M  S1200
# 2   110449721117            West S Lp     M  S1200
# 3   110449719101               W S Lp     M  S1200
# 4  1106039033336               E S Lp     M  S1200
#
#                                             geometry  LengthMI
# 0  LINESTRING (1791293.798 7623070.326, 1791122.4...  0.220021
# 1  LINESTRING (1791294.231 7623081.564, 1791073.7...  0.221517
# 2  LINESTRING (1668852.254 7566582.529, 1668869.5...  0.624275
# 3  LINESTRING (1668373.606 7566294.178, 1668459.8...  0.347292
# 4  LINESTRING (1669708.783 7567107.535, 1669779.6...  1.388956

# %%
np.sum(roadp.LengthMI)
# Out:
# np.float64(63284.38092393681)

# %% [markdown]
# <h5> Approximate road area in Texas Highways

# %%
width = 35 #Roads occupy 75 metersHighways in total for buffer its half
roadsb = roadp.copy()
roadsb['geometry'] = roadsb.geometry.buffer(width)

# %%
roadsb.head()
# Out:
#         LINEARID             FULLNAME RTTYP  MTFCC  \
# 0  1102671600066  S Walton Walker Rmp     M  S1200
# 1  1102671599582  S Walton Walker Rmp     M  S1200
# 2   110449721117            West S Lp     M  S1200
# 3   110449719101               W S Lp     M  S1200
# 4  1106039033336               E S Lp     M  S1200
#
#                                             geometry  LengthMI
# 0  POLYGON ((1791124.277 7623026.222, 1791122.834...  0.220021
# 1  POLYGON ((1791074.521 7623041.707, 1791072.581...  0.221517
# 2  POLYGON ((1668850.606 7566623.114, 1668850.806...  0.624275
# 3  POLYGON ((1668442.481 7566371.953, 1668588.38 ...  0.347292
# 4  POLYGON ((1669761.635 7567180.233, 1669762.734...  1.388956

# %%
roadsb['AreaSQMI'] = roadsb.area*np.power(0.0006213712,2)
roadsb.head()
# Out:
#         LINEARID             FULLNAME RTTYP  MTFCC  \
# 0  1102671600066  S Walton Walker Rmp     M  S1200
# 1  1102671599582  S Walton Walker Rmp     M  S1200
# 2   110449721117            West S Lp     M  S1200
# 3   110449719101               W S Lp     M  S1200
# 4  1106039033336               E S Lp     M  S1200
#
#                                             geometry  LengthMI  AreaSQMI
# 0  POLYGON ((1791124.277 7623026.222, 1791122.834...  0.220021  0.011053
# 1  POLYGON ((1791074.521 7623041.707, 1791072.581...  0.221517  0.011118
# 2  POLYGON ((1668850.606 7566623.114, 1668850.806...  0.624275  0.028637
# 3  POLYGON ((1668442.481 7566371.953, 1668588.38 ...  0.347292  0.016589
# 4  POLYGON ((1669761.635 7567180.233, 1669762.734...  1.388956  0.061897

# %%
sum(roadsb.AreaSQMI)
# Out:
# 2764.9544684026887

# %% [markdown]
# <h5>Find the length per County (Spatial Join)

# %%
roadscty = gpd.overlay(roadp,texasp,how ='intersection')

# %%
roadscty.columns
# Out:
# Index(['LINEARID', 'FULLNAME', 'RTTYP', 'MTFCC', 'LengthMI', 'CMPTRL_CNT',
#        'DPS_CNTY_N', 'FIPS_ST_CN', 'TXDOT_CNTY', 'TXDOT_DIST', 'CNTY_NM',
#        'CNTY_NBR', 'DIST_NBR', 'GID', 'AreaSQMI', 'geometry'],
#       dtype='object')

# %%
roadscty.head()
# Out:
#         LINEARID             FULLNAME RTTYP  MTFCC  LengthMI  CMPTRL_CNT  \
# 0  1102671600066  S Walton Walker Rmp     M  S1200  0.220021          57
# 1  1102671599582  S Walton Walker Rmp     M  S1200  0.221517          57
# 2   110449721117            West S Lp     M  S1200  0.624275          72
# 3   110449719101               W S Lp     M  S1200  0.347292          72
# 4  1106039033336               E S Lp     M  S1200  1.388956          72
#
#    DPS_CNTY_N FIPS_ST_CN  TXDOT_CNTY  TXDOT_DIST CNTY_NM  CNTY_NBR  DIST_NBR  \
# 0          57      48113          57          18  Dallas        57        18
# 1          57      48113          57          18  Dallas        57        18
# 2          72      48143          73           2   Erath        73         2
# 3          72      48143          73           2   Erath        73         2
# 4          72      48143          73           2   Erath        73         2
#
#    GID     AreaSQMI                                           geometry
# 0  177   908.412098  LINESTRING (1791293.798 7623070.326, 1791122.4...
# 1  177   908.412098  LINESTRING (1791294.231 7623081.564, 1791073.7...
# 2  149  1087.397818  LINESTRING (1668852.254 7566582.529, 1668869.5...
# 3  149  1087.397818  LINESTRING (1668373.606 7566294.178, 1668459.8...
# 4  149  1087.397818  LINESTRING (1669708.783 7567107.535, 1669779.6...

# %%
roadsctyg = roadscty.groupby('CNTY_NM')['LengthMI'].sum().reset_index()

# %%
roadsctyg.head()
# Out:
#     CNTY_NM    LengthMI
# 0  Anderson  332.251680
# 1   Andrews  565.221778
# 2  Angelina  366.663162
# 3   Aransas  100.591255
# 4    Archer  322.382896

# %%
roadsctyg.sort_values(by='LengthMI',ascending=False)
# Out:
#        CNTY_NM     LengthMI
# 100     Harris  2861.070723
# 56      Dallas  2023.644947
# 219    Tarrant  1775.085937
# 14       Bexar  1530.842074
# 69     El Paso   938.478005
# ..         ...          ...
# 31        Camp    55.584974
# 196    Roberts    53.965410
# 212  Somervell    53.032941
# 16      Borden    48.887280
# 150     Loving    37.792269
#
# [254 rows x 2 columns]

# %%
roadsctyg.loc[(roadsctyg)['CNTY_NM']=='Jefferson']
# Out:
#        CNTY_NM    LengthMI
# 122  Jefferson  718.496869

# %%
len(roadsctyg)
# Out:
# 254

# %%
type(roadsctyg)
# Out:
# pandas.core.frame.DataFrame

# %%
texasp.columns
# Out:
# Index(['CMPTRL_CNT', 'DPS_CNTY_N', 'FIPS_ST_CN', 'TXDOT_CNTY', 'TXDOT_DIST',
#        'CNTY_NM', 'CNTY_NBR', 'DIST_NBR', 'GID', 'geometry', 'AreaSQMI'],
#       dtype='object')

# %%
texasp = texasp.merge(roadsctyg,on='CNTY_NM')

# %%
texasp.columns
# Out:
# Index(['CMPTRL_CNT', 'DPS_CNTY_N', 'FIPS_ST_CN', 'TXDOT_CNTY', 'TXDOT_DIST',
#        'CNTY_NM', 'CNTY_NBR', 'DIST_NBR', 'GID', 'geometry', 'AreaSQMI',
#        'LengthMI'],
#       dtype='object')

# %%
texasp['RDdensity'] = texasp.LengthMI/texasp.AreaSQMI

# %%
texasp.head()
# Out:
#    CMPTRL_CNT  DPS_CNTY_N FIPS_ST_CN  TXDOT_CNTY  TXDOT_DIST   CNTY_NM  \
# 0         232         232      48463         232          15    Uvalde
# 1         143         143      48285         143          13    Lavaca
# 2          20          20      48039          20          12  Brazoria
# 3         241         241      48481         241          13   Wharton
# 4         163         163      48325         163          15    Medina
#
#    CNTY_NBR  DIST_NBR  GID                                           geometry  \
# 0       232        15   35  POLYGON ((1548581.291 7218735.879, 1548468.505...
# 1       143        13   36  POLYGON ((1802991.419 7283200.383, 1803004.233...
# 2        20        12   37  POLYGON ((1955932.657 7285025.893, 1955942.414...
# 3       241        13   38  POLYGON ((1869676.725 7285704.18, 1869702.421 ...
# 4       163        15   39  POLYGON ((1557004.141 7228370.693, 1557000.037...
#
#       AreaSQMI    LengthMI  RDdensity
# 0  1564.693610  216.030887   0.138066
# 1   971.076790  306.607246   0.315739
# 2  1486.249672  632.516688   0.425579
# 3  1094.348572  307.706844   0.281178
# 4  1339.619141  332.320930   0.248071

# %%
# Plot Road Density of Texas Counties
texasp.plot(column='RDdensity', legend=True)

import matplotlib.pyplot as plt

plt.xlabel('Easting')
plt.ylabel('Northing')
plt.grid()
plt.title('Road Density of Texas Counties')
plt.show()

# %% [markdown]
# <h1><font color = 'Green'> <center>GIS Apps in Engineering: Assignment 4</h1>
# <h3><font color = 'blue'> <center>Lajuk</h3>

# %% [markdown]
# <h5> Problem Statement

# %% [markdown]
# The goal is to create a logistic regression model for predicting bridge condition(susceptibility to failure), We shall use Age, ADT
#                                                  Material, Reconst as our *independent Variables* We shall recode the lowest bridge rating as Satisfactory (5-9) and Unsatisfactory (0-5)

# %% [markdown]
# # Read the 2024 data
#
# 1. Create latitudeDD and longitudeDD for plotting
#
# 2. Create a new FID (lat_lon)
#
# 3. Clean or remove duplicates
#
# 4. Recode lowest rating as a binary variable
#
# 6. Compute Age
#
# 7. Extract the required variables into a new dataframe
#
# 8. Perform train-test split
#
# 9. Fit the model on the training data
#
# 10. Evaluate the model using the testing data
#
# 11. Read 2025 data
#
# 12. Create new FID using the same concept as in step 3
#
# 13. Extract unique bridges in 2025
#
# 14. Make prediction using the model fit in step 9 and compare
#
# 15. Make plots and maps for visualization and analysis

# %%
# !pip install matplotlib-map-utils
# Out:
# Requirement already satisfied: matplotlib-map-utils in /opt/anaconda3/lib/python3.13/site-packages (3.1.0)
# Requirement already satisfied: matplotlib>=3.9.0 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib-map-utils) (3.10.0)
# Requirement already satisfied: cartopy>=0.23.0 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib-map-utils) (0.25.0)
# Requirement already satisfied: great-circle-calculator>=1.3.1 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib-map-utils) (1.3.1)
# Requirement already satisfied: numpy>=1.23 in /opt/anaconda3/lib/python3.13/site-packages (from cartopy>=0.23.0->matplotlib-map-utils) (2.1.3)
# Requirement already satisfied: shapely>=2.0 in /opt/anaconda3/lib/python3.13/site-packages (from cartopy>=0.23.0->matplotlib-map-utils) (2.1.1)
# Requirement already satisfied: packaging>=21 in /opt/anaconda3/lib/python3.13/site-packages (from cartopy>=0.23.0->matplotlib-map-utils) (24.2)
# Requirement already satisfied: pyshp>=2.3 in /opt/anaconda3/lib/python3.13/site-packages (from cartopy>=0.23.0->matplotlib-map-utils) (2.3.1)
# Requirement already satisfied: pyproj>=3.3.1 in /opt/anaconda3/lib/python3.13/site-packages (from cartopy>=0.23.0->matplotlib-map-utils) (3.6.1)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib>=3.9.0->matplotlib-map-utils) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib>=3.9.0->matplotlib-map-utils) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib>=3.9.0->matplotlib-map-utils) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib>=3.9.0->matplotlib-map-utils) (1.4.8)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib>=3.9.0->matplotlib-map-utils) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib>=3.9.0->matplotlib-map-utils) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib>=3.9.0->matplotlib-map-utils) (2.9.0.post0)
# Requirement already satisfied: certifi in /opt/anaconda3/lib/python3.13/site-packages (from pyproj>=3.3.1->cartopy>=0.23.0->matplotlib-map-utils) (2025.8.3)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib>=3.9.0->matplotlib-map-utils) (1.17.0)

# %%
import geopandas as gpd
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from shapely.geometry import Point, LineString, Polygon
import statsmodels.api as sm
import os
from matplotlib_map_utils.core.north_arrow import north_arrow

# %%
# function to parse lat-lon
def parsell(val, lat=True):
    s = str(val)
    if (len(s) == 8):     # Latitude format (DDMMSSss)
        deg = int(s[:2])
        minx = int(s[2:4])
        secx = int(s[4:]) / 100
    else:                 # Longitude format (DDDMMSSss)
        deg = int(s[:3])
        minx = int(s[3:5])
        secx = int(s[5:]) / 100

    if (lat == True):
        dd = deg + minx / 60 + secx / 3600
    else:                 # Western hemisphere longitudes are negative
        dd = deg + minx / 60 + secx / 3600
        dd = -1 * dd

    return dd

# %%
def dataprep(aa):
    Rat = aa.copy()
    yrb = pd.to_numeric(Rat.YEAR_BUILT_027,errors='coerce')
    yrc = pd.to_numeric(Rat.YEAR_RECONSTRUCTED_106,errors='coerce')
    Rat["age"] = 2024 - np.maximum(yrb,yrc)
    # Create Lat-Lon
    Rat.loc[:,"LATDD"] = parsellv(Rat.loc[:,["LAT_016"]],lat=True)
    Rat.loc[:,"LONDD"] = parsellv(Rat.loc[:,["LONG_017"]],lat=False)
    Rat["UNSAFE"] = np.where(Rat.loc[:,["LOWEST_RATING"]].astype(int)<6,1,0)
    return(Rat)

# %%
# Vectorized version of parsell
parsellv = np.vectorize(parsell)

# %%
path = '/Users/washemuzzamanlajuk/Desktop/Fall-2025/GIS/Assignment-4/NBI_TX'
os.chdir(path)

# %%
#Read 2024 NBI file
fname = "NBI2024.csv" 
a = pd.read_csv(fname, on_bad_lines='skip', dtype="str")
a.head()
# Out:
#   STATE_CODE_001 STRUCTURE_NUMBER_008 RECORD_TYPE_005A ROUTE_PREFIX_005B  \
# 0             48      0000000L2015318                1                 6
# 1             48      000021521-00101                1                 6
# 2             48      000021521-00181                1                 6
# 3             48      000021521-TMP20                1                 6
# 4             48      000021525-00012                1                 6
#
#   SERVICE_LEVEL_005C ROUTE_NUMBER_005D DIRECTION_005E HIGHWAY_DISTRICT_002  \
# 0                  4             00000              0                   00
# 1                  0             00000              0                   02
# 2                  0             00000              0                   02
# 3                  1             00000              0                   02
# 4                  0             00000              0                   02
#
#   COUNTY_CODE_003 PLACE_CODE_004  ... BRIDGE_LEN_IND_112 SCOUR_CRITICAL_113  \
# 0             375          00000  ...                  Y                  7
# 1             071          00000  ...                  Y                  8
# 2             071          00000  ...                  Y                  8
# 3             071          00000  ...                  Y                  8
# 4             245          00000  ...                  Y                  8
#
#   FUTURE_ADT_114 YEAR_OF_FUTURE_ADT_115 MIN_NAV_CLR_MT_116 FED_AGENCY  \
# 0            200                   2035                NaN          Y
# 1              1                   2042                NaN          Y
# 2              1                   2042                NaN          Y
# 3            150                   2042                NaN          Y
# 4            120                   2042                NaN          Y
#
#   SUBMITTED_BY BRIDGE_CONDITION LOWEST_RATING DECK_AREA
# 0           68                F             6    169.84
# 1           63                F             6    150.72
# 2           63                G             7      74.4
# 3           63                G             7     91.91
# 4           63                P             4     204.3
#
# [5 rows x 123 columns]

# %%
a['FID'] = a.LAT_016.astype(str) + "_" + a.LONG_017.astype(str)
a['FID']
# Out:
# 0        35185702_101560762
# 1        29362100_094272880
# 2        29362940_094254920
# 3        29365160_094324020
# 4        29413300_094044860
#                 ...
# 56724    31495329_106183492
# 56725    32430233_096561253
# 56726    32424987_096560305
# 56727    32424560_096561340
# 56728    29283700_098252680
# Name: FID, Length: 56729, dtype: object

# %%
a.head()
# Out:
#   STATE_CODE_001 STRUCTURE_NUMBER_008 RECORD_TYPE_005A ROUTE_PREFIX_005B  \
# 0             48      0000000L2015318                1                 6
# 1             48      000021521-00101                1                 6
# 2             48      000021521-00181                1                 6
# 3             48      000021521-TMP20                1                 6
# 4             48      000021525-00012                1                 6
#
#   SERVICE_LEVEL_005C ROUTE_NUMBER_005D DIRECTION_005E HIGHWAY_DISTRICT_002  \
# 0                  4             00000              0                   00
# 1                  0             00000              0                   02
# 2                  0             00000              0                   02
# 3                  1             00000              0                   02
# 4                  0             00000              0                   02
#
#   COUNTY_CODE_003 PLACE_CODE_004  ... SCOUR_CRITICAL_113 FUTURE_ADT_114  \
# 0             375          00000  ...                  7            200
# 1             071          00000  ...                  8              1
# 2             071          00000  ...                  8              1
# 3             071          00000  ...                  8            150
# 4             245          00000  ...                  8            120
#
#   YEAR_OF_FUTURE_ADT_115 MIN_NAV_CLR_MT_116 FED_AGENCY SUBMITTED_BY  \
# 0                   2035                NaN          Y           68
# 1                   2042                NaN          Y           63
# 2                   2042                NaN          Y           63
# 3                   2042                NaN          Y           63
# 4                   2042                NaN          Y           63
#
#   BRIDGE_CONDITION LOWEST_RATING DECK_AREA                 FID
# 0                F             6    169.84  35185702_101560762
# 1                F             6    150.72  29362100_094272880
# 2                G             7      74.4  29362940_094254920
# 3                G             7     91.91  29365160_094324020
# 4                P             4     204.3  29413300_094044860
#
# [5 rows x 124 columns]

# %%
len(a)
# Out:
# 56729

# %%
# Remove duplicates based on FID
aa = a[~a.duplicated(subset=['FID'], keep=False)].copy()
len(aa)
# Out:
# 56571

# %%
aa.head()
# Out:
#   STATE_CODE_001 STRUCTURE_NUMBER_008 RECORD_TYPE_005A ROUTE_PREFIX_005B  \
# 0             48      0000000L2015318                1                 6
# 1             48      000021521-00101                1                 6
# 2             48      000021521-00181                1                 6
# 3             48      000021521-TMP20                1                 6
# 4             48      000021525-00012                1                 6
#
#   SERVICE_LEVEL_005C ROUTE_NUMBER_005D DIRECTION_005E HIGHWAY_DISTRICT_002  \
# 0                  4             00000              0                   00
# 1                  0             00000              0                   02
# 2                  0             00000              0                   02
# 3                  1             00000              0                   02
# 4                  0             00000              0                   02
#
#   COUNTY_CODE_003 PLACE_CODE_004  ... SCOUR_CRITICAL_113 FUTURE_ADT_114  \
# 0             375          00000  ...                  7            200
# 1             071          00000  ...                  8              1
# 2             071          00000  ...                  8              1
# 3             071          00000  ...                  8            150
# 4             245          00000  ...                  8            120
#
#   YEAR_OF_FUTURE_ADT_115 MIN_NAV_CLR_MT_116 FED_AGENCY SUBMITTED_BY  \
# 0                   2035                NaN          Y           68
# 1                   2042                NaN          Y           63
# 2                   2042                NaN          Y           63
# 3                   2042                NaN          Y           63
# 4                   2042                NaN          Y           63
#
#   BRIDGE_CONDITION LOWEST_RATING DECK_AREA                 FID
# 0                F             6    169.84  35185702_101560762
# 1                F             6    150.72  29362100_094272880
# 2                G             7      74.4  29362940_094254920
# 3                G             7     91.91  29365160_094324020
# 4                P             4     204.3  29413300_094044860
#
# [5 rows x 124 columns]

# %%
#create a Lat-Lon
latx = aa.loc[:,["LAT_016"]]
aa.loc[:,"LATDD"] = parsellv(latx,lat=True)

# %%
lonx = aa.loc[:, "LONG_017"]
aa.loc[:, "LONDD"] = parsellv(lonx, lat=False)

# %%
aa.LONDD
# Out:
# 0       -101.935450
# 1        -94.458000
# 2        -94.430333
# 3        -94.544500
# 4        -94.080167
#             ...
# 56724   -106.309700
# 56725    -96.936814
# 56726    -96.934181
# 56727    -96.937056
# 56728    -98.424111
# Name: LONDD, Length: 56571, dtype: float64

# %%
aa.LOWEST_RATING.describe()
# Out:
# count     56571
# unique       10
# top           7
# freq      27960
# Name: LOWEST_RATING, dtype: object

# %%
aa.LOWEST_RATING.unique()
# Out:
# array(['6', '7', '4', '8', '3', '5', '9', '2', '1', '0'], dtype=object)

# %%
Rat = aa.loc[:,["LOWEST_RATING"]].astype(int)
aa["UNSAFE"] = np.where(Rat<6,1,0)

# %%
aa.head()
# Out:
#   STATE_CODE_001 STRUCTURE_NUMBER_008 RECORD_TYPE_005A ROUTE_PREFIX_005B  \
# 0             48      0000000L2015318                1                 6
# 1             48      000021521-00101                1                 6
# 2             48      000021521-00181                1                 6
# 3             48      000021521-TMP20                1                 6
# 4             48      000021525-00012                1                 6
#
#   SERVICE_LEVEL_005C ROUTE_NUMBER_005D DIRECTION_005E HIGHWAY_DISTRICT_002  \
# 0                  4             00000              0                   00
# 1                  0             00000              0                   02
# 2                  0             00000              0                   02
# 3                  1             00000              0                   02
# 4                  0             00000              0                   02
#
#   COUNTY_CODE_003 PLACE_CODE_004  ... MIN_NAV_CLR_MT_116 FED_AGENCY  \
# 0             375          00000  ...                NaN          Y
# 1             071          00000  ...                NaN          Y
# 2             071          00000  ...                NaN          Y
# 3             071          00000  ...                NaN          Y
# 4             245          00000  ...                NaN          Y
#
#   SUBMITTED_BY BRIDGE_CONDITION LOWEST_RATING DECK_AREA                 FID  \
# 0           68                F             6    169.84  35185702_101560762
# 1           63                F             6    150.72  29362100_094272880
# 2           63                G             7      74.4  29362940_094254920
# 3           63                G             7     91.91  29365160_094324020
# 4           63                P             4     204.3  29413300_094044860
#
#        LATDD       LONDD UNSAFE
# 0  35.315839 -101.935450      0
# 1  29.605833  -94.458000      0
# 2  29.608167  -94.430333      0
# 3  29.614333  -94.544500      0
# 4  29.692500  -94.080167      1
#
# [5 rows x 127 columns]

# %%
sum(aa.UNSAFE)
# Out:
# 4818

# %%
len(aa)
# Out:
# 56571

# %% [markdown]
# <h3> Compute Age

# %%
aa.head()
# Out:
#   STATE_CODE_001 STRUCTURE_NUMBER_008 RECORD_TYPE_005A ROUTE_PREFIX_005B  \
# 0             48      0000000L2015318                1                 6
# 1             48      000021521-00101                1                 6
# 2             48      000021521-00181                1                 6
# 3             48      000021521-TMP20                1                 6
# 4             48      000021525-00012                1                 6
#
#   SERVICE_LEVEL_005C ROUTE_NUMBER_005D DIRECTION_005E HIGHWAY_DISTRICT_002  \
# 0                  4             00000              0                   00
# 1                  0             00000              0                   02
# 2                  0             00000              0                   02
# 3                  1             00000              0                   02
# 4                  0             00000              0                   02
#
#   COUNTY_CODE_003 PLACE_CODE_004  ... MIN_NAV_CLR_MT_116 FED_AGENCY  \
# 0             375          00000  ...                NaN          Y
# 1             071          00000  ...                NaN          Y
# 2             071          00000  ...                NaN          Y
# 3             071          00000  ...                NaN          Y
# 4             245          00000  ...                NaN          Y
#
#   SUBMITTED_BY BRIDGE_CONDITION LOWEST_RATING DECK_AREA                 FID  \
# 0           68                F             6    169.84  35185702_101560762
# 1           63                F             6    150.72  29362100_094272880
# 2           63                G             7      74.4  29362940_094254920
# 3           63                G             7     91.91  29365160_094324020
# 4           63                P             4     204.3  29413300_094044860
#
#        LATDD       LONDD UNSAFE
# 0  35.315839 -101.935450      0
# 1  29.605833  -94.458000      0
# 2  29.608167  -94.430333      0
# 3  29.614333  -94.544500      0
# 4  29.692500  -94.080167      1
#
# [5 rows x 127 columns]

# %%
#YEARS_BUILT_027
#YEARS_RECONSTRUCTED_106
yrb = pd.to_numeric(aa.YEAR_BUILT_027, errors ="coerce")
yrc = pd.to_numeric(aa.YEAR_RECONSTRUCTED_106, errors ="coerce")
age = 2024 - np.maximum(yrb,yrc)
age
# Out:
# 0        16.0
# 1        19.0
# 2        19.0
# 3        12.0
# 4        17.0
#          ...
# 56724    11.0
# 56725     NaN
# 56726     NaN
# 56727     NaN
# 56728     NaN
# Length: 56571, dtype: float64

# %%
aa["AGE"] = age

# %%
aa = aa.loc[aa["LATDD"] > 25]
aa.describe()
# Out:
#               LATDD         LONDD        UNSAFE           AGE
# count  56570.000000  56570.000000  56570.000000  56514.000000
# mean      31.224550    -97.512845      0.085169     37.289397
# std        1.815607      2.262591      0.279135     22.415676
# min       25.873389   -106.618869      0.000000      0.000000
# 25%       29.800444    -98.434671      0.000000     18.000000
# 50%       31.267235    -97.160800      0.000000     35.000000
# 75%       32.744215    -95.970334      0.000000     55.000000
# max       36.482353    -93.520178      1.000000    124.000000

# %%
aa.describe()
# Out:
#               LATDD         LONDD        UNSAFE           AGE
# count  56570.000000  56570.000000  56570.000000  56514.000000
# mean      31.224550    -97.512845      0.085169     37.289397
# std        1.815607      2.262591      0.279135     22.415676
# min       25.873389   -106.618869      0.000000      0.000000
# 25%       29.800444    -98.434671      0.000000     18.000000
# 50%       31.267235    -97.160800      0.000000     35.000000
# 75%       32.744215    -95.970334      0.000000     55.000000
# max       36.482353    -93.520178      1.000000    124.000000

# %%
txdis = gpd.read_file("TX_dissolved.gpkg")
txdis = txdis.to_crs(epsg=4326)
print(txdis.crs)
txdis.plot()
plt.show
# Out:
# EPSG:4326
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
txdis.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
from shapely.geometry import Point

# %%
bridges = gpd.GeoDataFrame(
    aa,
    geometry=gpd.points_from_xy(aa["LONDD"], aa["LATDD"]),
    crs="EPSG:4326"
)

# %%
# Match projection to Texas dissolved map
bridges = bridges.to_crs(txdis.crs)

# %%
# Define a simple dictionary that maps UNSAFE values to colors
colormap = {0: "blue", 1: "red"}

# Add a new column 'color' to the bridges dataframe based on UNSAFE values
bridges["color"] = bridges["UNSAFE"].map(colormap)

# Create a figure and axis object with width=10, height=8 (inches)
fig, ax = plt.subplots(figsize=(10, 8))

# Plot the Texas dissolved boundary (outline only, no fill)
txdis.plot(ax=ax, facecolor="none", edgecolor="black", linewidth=2)

# Add a title to the map
plt.title("Texas dissolved boundary")

# Show the final plot
plt.show()

# %%
# Replace each polygon with one built only from its exterior (removes holes or other objects inside)
txdis["geometry"] = txdis["geometry"].apply(lambda geom: Polygon(geom.exterior))
txdis.plot( facecolor="none", edgecolor="black",)
# Out:
# <Axes: >

# %%
# Define a color mapping: 0 → blue (safe), 1 → red (unsafe)
colormap = {0: "blue", 1: "red"}

# Create a new 'color' column in the bridges GeoDataFrame
# Each bridge gets a color based on its UNSAFE value
bridges["color"] = bridges["UNSAFE"].map(colormap)

# Create a matplotlib figure and axis with specified size
fig, ax = plt.subplots(figsize=(10, 8))

# Plot the Texas dissolved boundary (transparent fill, black outline, thick border)
txdis.plot(ax=ax, facecolor="none", edgecolor="black", linewidth=2)

# Plot the bridges on top, colored by safety status, with very small marker size
bridges.plot(ax=ax, color=bridges["color"], markersize=1)

# Add north arrow (matplotlib-map-utils style)
north_arrow(
    ax=ax,
    location="lower left",
    rotation={"crs": 4326, "reference": "center"},
    scale=0.3
)
# Add a descriptive title to the map
plt.title("Texas Bridges: Safe (Blue) vs Unsafe (Red)")

# Display the final plot
plt.show()

# %%
import matplotlib
print(matplotlib.__version__)
# Out:
# 3.10.0

# %%
import cartopy
print(cartopy.__version__)
# Out:
# 0.25.0

# %% [markdown]
# <h3> Process NBI2025 File and extract Data

# %%
#Read 2024 NBI file
fname = "NBI2025.csv" 
b = pd.read_csv(fname, on_bad_lines='skip', dtype="str")
b.head()
# Out:
#   STATE_CODE_001 STRUCTURE_NUMBER_008 RECORD_TYPE_005A ROUTE_PREFIX_005B  \
# 0             48      000021521-00101                1                 6
# 1             48      000021521-00181                1                 6
# 2             48      000021521-TMP20                1                 6
# 3             48      000021525-00012                1                 6
# 4             48      000021525-00014                1                 6
#
#   SERVICE_LEVEL_005C ROUTE_NUMBER_005D DIRECTION_005E HIGHWAY_DISTRICT_002  \
# 0                  0             00000              0                   02
# 1                  0             00000              0                   02
# 2                  1             00000              0                   02
# 3                  0             00000              0                   02
# 4                  0             00000              0                   02
#
#   COUNTY_CODE_003 PLACE_CODE_004  ... BRIDGE_LEN_IND_112 SCOUR_CRITICAL_113  \
# 0             071          00000  ...                  Y                  8
# 1             071          00000  ...                  Y                  8
# 2             071          00000  ...                  Y                  8
# 3             245          00000  ...                  Y                  5
# 4             245          00000  ...                  Y                  5
#
#   FUTURE_ADT_114 YEAR_OF_FUTURE_ADT_115 MIN_NAV_CLR_MT_116 FED_AGENCY  \
# 0              1                   2042                NaN          Y
# 1              1                   2042                NaN          Y
# 2            150                   2042                NaN          Y
# 3            120                   2044                NaN          Y
# 4             20                   2042                NaN          Y
#
#   SUBMITTED_BY BRIDGE_CONDITION LOWEST_RATING DECK_AREA
# 0           63                F             6    150.72
# 1           63                G             7      74.4
# 2           63                G             7     91.91
# 3           63                P             4     204.3
# 4           63                G             7    157.92
#
# [5 rows x 123 columns]

# %%
b['FID'] = b.LAT_016.astype(str) + "_" + b.LONG_017.astype(str)
b['FID']
# Out:
# 0        29362100_094272880
# 1        29362940_094254920
# 2        29365160_094324020
# 3        29413300_094044860
# 4        29412100_094092940
#                 ...
# 56946    31495329_106183492
# 56947    32430233_096561253
# 56948    32424987_096560305
# 56949    32424560_096561340
# 56950    29283700_098252680
# Name: FID, Length: 56951, dtype: object

# %%
bb = b[~b.duplicated(subset=['FID'], keep=False)].copy()
len(bb)
# Out:
# 56847

# %%
# Filter rows of bb whose FID exists in aa["FID"]
new_records = bb[~bb["FID"].isin(aa["FID"])]

# Count how many records matched
len(new_records)
# Out:
# 52172

# %%
dat2025 = dataprep(new_records)

# %%
dat2025.head()
# Out:
#    STATE_CODE_001 STRUCTURE_NUMBER_008 RECORD_TYPE_005A ROUTE_PREFIX_005B  \
# 17             48      010600013603019                1                 3
# 18             48      010600013603026                1                 3
# 19             48      010600013603028                1                 3
# 20             48      010600013603083                1                 3
# 21             48      010600013603131                1                 3
#
#    SERVICE_LEVEL_005C ROUTE_NUMBER_005D DIRECTION_005E HIGHWAY_DISTRICT_002  \
# 17                  1             00024              0                   01
# 18                  1             00024              0                   01
# 19                  1             00024              0                   01
# 20                  1             00024              0                   01
# 21                  1             00024              0                   01
#
#    COUNTY_CODE_003 PLACE_CODE_004  ... FED_AGENCY SUBMITTED_BY  \
# 17             119          00000  ...          N           48
# 18             119          00000  ...          N           48
# 19             119          00000  ...          N           48
# 20             119          00000  ...          N           48
# 21             119          75448  ...          N           48
#
#    BRIDGE_CONDITION LOWEST_RATING DECK_AREA                 FID   age  \
# 17                F             6      98.6  33184193_095492433   8.0
# 18                G             7    116.62  33200637_095460208   7.0
# 19                F             5    584.24  33214533_095432060  65.0
# 20                F             6    142.71  33225734_095413334  57.0
# 21                G             7   1115.08  33180357_095505198   6.0
#
#         LATDD      LONDD UNSAFE
# 17  33.311647 -95.823425      0
# 18  33.335103 -95.767244      0
# 19  33.362592 -95.722389      1
# 20  33.382594 -95.692594      0
# 21  33.300992 -95.847772      0
#
# [5 rows x 128 columns]

# %%
dat2024 = dataprep(aa)
dat2024.head()
# Out:
#   STATE_CODE_001 STRUCTURE_NUMBER_008 RECORD_TYPE_005A ROUTE_PREFIX_005B  \
# 0             48      0000000L2015318                1                 6
# 1             48      000021521-00101                1                 6
# 2             48      000021521-00181                1                 6
# 3             48      000021521-TMP20                1                 6
# 4             48      000021525-00012                1                 6
#
#   SERVICE_LEVEL_005C ROUTE_NUMBER_005D DIRECTION_005E HIGHWAY_DISTRICT_002  \
# 0                  4             00000              0                   00
# 1                  0             00000              0                   02
# 2                  0             00000              0                   02
# 3                  1             00000              0                   02
# 4                  0             00000              0                   02
#
#   COUNTY_CODE_003 PLACE_CODE_004  ... SUBMITTED_BY BRIDGE_CONDITION  \
# 0             375          00000  ...           68                F
# 1             071          00000  ...           63                F
# 2             071          00000  ...           63                G
# 3             071          00000  ...           63                G
# 4             245          00000  ...           63                P
#
#   LOWEST_RATING DECK_AREA                 FID      LATDD       LONDD UNSAFE  \
# 0             6    169.84  35185702_101560762  35.315839 -101.935450      0
# 1             6    150.72  29362100_094272880  29.605833  -94.458000      0
# 2             7      74.4  29362940_094254920  29.608167  -94.430333      0
# 3             7     91.91  29365160_094324020  29.614333  -94.544500      0
# 4             4     204.3  29413300_094044860  29.692500  -94.080167      1
#
#     AGE   age
# 0  16.0  16.0
# 1  19.0  19.0
# 2  19.0  19.0
# 3  12.0  12.0
# 4  17.0  17.0
#
# [5 rows x 129 columns]

# %%
print(aa.columns)
# Out:
# Index(['STATE_CODE_001', 'STRUCTURE_NUMBER_008', 'RECORD_TYPE_005A',
#        'ROUTE_PREFIX_005B', 'SERVICE_LEVEL_005C', 'ROUTE_NUMBER_005D',
#        'DIRECTION_005E', 'HIGHWAY_DISTRICT_002', 'COUNTY_CODE_003',
#        'PLACE_CODE_004',
#        ...
#        'SUBMITTED_BY', 'BRIDGE_CONDITION', 'LOWEST_RATING', 'DECK_AREA', 'FID',
#        'LATDD', 'LONDD', 'UNSAFE', 'AGE', 'RECON'],
#       dtype='object', length=129)

# %%
# STRUCTURE_KIND_043A, ADT_029, 'FID', 'LATDD', 'LONDD', 'UNSAFE', 'AGE'; # YEAR_RECONSTRUCTED_106

# Convert YEAR_RECONSTRUCTED_106 to numeric safely
aa["YEAR_RECONSTRUCTED_106"] = pd.to_numeric(aa["YEAR_RECONSTRUCTED_106"], errors="coerce")
aa["RECON"] = np.where(aa["YEAR_RECONSTRUCTED_106"] > 0, 1, 0)

dat2025["YEAR_RECONSTRUCTED_106"] = pd.to_numeric(dat2025["YEAR_RECONSTRUCTED_106"], errors="coerce")
dat2025["RECON"] = np.where(dat2025["YEAR_RECONSTRUCTED_106"] > 0, 1, 0)

# %%
cols = ["FID", "LATDD", "LONDD", "AGE", "RECON", "ADT_029", "STRUCTURE_KIND_043A","UNSAFE"]

# Make a copy of aa
bb = aa.copy()

# Select only the desired columns and export to CSV
bb = bb.loc[:, cols]
bb.to_csv("NBIFINAL2024.csv", index=False)

# %%
bb = dat2025.copy()

# Select only the desired columns and export to CSV
bb = bb.loc[:, cols]
bb.to_csv("NBIUNIQUE2025.csv", index=False)
